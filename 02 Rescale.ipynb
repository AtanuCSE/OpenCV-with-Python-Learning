# %% [markdown]
# # Rescaling Image and Video

# %%
import cv2 as cv
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv.imread("Photos/dog2.jpg")

# %% [markdown]
# frame.shape[1] means image width, frame.shape[0] means image height

# %%
def rescaleFrame(frame, scale=0.50):
    width = int(frame.shape[1] * scale)
    height = int(frame.shape[0] * scale)
    dimensions = (width, height)
    
    return cv.resize(frame, dimensions, interpolation=cv.INTER_AREA)

# %% [markdown]
# We are resizing it by 50%

# %% [markdown]
# ### For Image

# %%
resized_image = rescaleFrame(img)
#Show the image with matplotlib
RGB_img = cv.cvtColor(resized_image, cv.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()

# %% [markdown]
# ### For Video

# %%
capture = cv.VideoCapture("Videos/test_vid2.mp4")

while True:
    # Capture frame-by-frame
    isTrue, frame = capture.read()
    
    frame_resized = rescaleFrame(frame)
    
    # UNCOMMENT TO SEE THE VIDEO
    # cv.imshow('Resized frame', frame_resized)
    
    
    if cv.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Resize & Crop Images with __OpenCV Direct Functions__

# %%
img = cv.imread("Photos/dog2.jpg")
resized = cv.resize(img, (500,500), interpolation=cv.INTER_CUBIC)
# interpolation=cv.INTERPOLATION is default but CUBIC produces better result
# However, cubic is slow
#Show the image with matplotlib
RGB_img = cv.cvtColor(resized, cv.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()

# %%
img = cv.imread("Photos/dog1.jpg")
# Cropping
cropped = img[150:200, 150:400]
#Show the image with matplotlib
if cropped is not None: 
    RGB_img = cv.cvtColor(cropped, cv.COLOR_BGR2RGB)
    plt.imshow(RGB_img)
    plt.show()
else:
    print("empty frame")
